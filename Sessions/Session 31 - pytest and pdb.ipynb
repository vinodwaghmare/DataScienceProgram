# %%
Agile

# %%
1 Requirement Analysis
2 Design phase
3 Development phase
4 Testing
5 Deployment and mantainance

# %%
1 Requirement Analysis.
 - Eg :- Online shopping website
    - Requitements will be finalised
    -Scope of development
    - No scope of development
    
2 Design phase.
    -Here  Architects will have main role.
    -Based on requirement:-
        - technology stack, which database should be be used or not
        - which prog language should be used,requirement of ML is their 
          or not
        - No. of users how many servers required whether thier will be cloud or not.
        
3 Development phase.
        - Developers will code and implement features then test at their end.
    
4 Testing.
        - Check everything is working fine or not.
        - Defect lifecycle
        
5 Deployment and mantainance.
        - Support and maintainance team.

# %% [markdown]
# Test Models:
#     1)Agile
#     2)Scram
#     3)Waterfall
#     4)Iteraton
#     5)Traditional
#     6)Spiral
#
# Waterfall Model
#
# Problem with waterfall model once we closed the design phase we allocated resources which will be end to allocate again.
#
#
# Iterative model
#
# Instead of implementing entire system directly it will divide the entire appllication into multiple iteration
# same cycle will happen mutiple times we can allocate resources again.
#
#
# Agile:
#
# Agile says their should not separation between development phase and testing phase to achieve common goal.
# Collab with each other DP and TP.

# %%
Agile User story
As A user I want func to login to the system.

# %%
In Agile in collab with DP and TP but one team is not a part of agile team 
    is deployment.
    
DevOPS :- Entire pipline from development to deployment way to achieve through automation.
    Whenever someone is writing the code their has to be some unit case once its unit tested the functional testing
    will try  built some framework code should be exe the building and deploying the application should also be part
    of it.
Development and Operation teams also try to collab now.

1) src management - git
2) build management - genhins
3) cloud - For deployment
4) Cotainer - Docker

tools for automation testing.

# %%
TDD : Test driven development 
    focusing on test case
BDD : Behaviour driven development 
     collaboration with business team to achieve end level/final goal

# %%
TDD:
    As developer before writing code I will first write all the possible test cases which are positive and negative test 
cases 
an I will write func for each test case will fail first
and then write enough code to pass the Unit test case.
Refactoring stage - 


Design login :
   Test Case 1: login form should work for valid username and password.
   Test Case 2: If my username and password are blank then display this error message.

# %%
BDD :
    Enable the collab with business,development and testing team and discuss each and every example and it will become
    our test case.
    So chance of writing code in wrong understanding will be minimized.

# %%
Gap Analysis : discussion with business team to solve tester query in the document of required features.
               inorder to check whether features are implementing  or not.

# %%
story points.

# %%
5 features
5 user stories

40/50
38/50

# %%
gira tool to handle agile

# %%
code => py1 func1
           func2
           func3
        py2

Test
    test_py => any file containing test case it should always start with filename
              test
    test_py1
        test_func1
        test_func2
        test_func3
    test_py2

# %%
pytest => when we execute pytest every test file and test func starts with name test will get executed.

# %%
 assert 10 == 10 compares 2 values if valid no error else assertion 
#                 error.
Validate

# %%
assert 10 == 11
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-30ca923ee8cb> in <module>
# ----> 1 assert 10 == 11
#
# AssertionError:

# %%
regression testing - test crictical features
Categorizing a func like key_present and linear search func it has functionality marks
For that pytest is providing markers

# %%
execute all test and all func : pytest -v (-v what failed or passed)
exe specific file: pytest filename.py
exe specific func : pytest -v filename.py:: func_name
            
Set the marker 
@pytest.mark.marker_name
pytest - v -m "marker_name"

# %%
src :
    pkg1
        py_1
        py_2
        
test:
    test_py1
    test_py2

# %%
import pytest
help(pytest)
# Out:
# Help on module pytest:
#
# NAME
#     pytest - pytest: unit and functional testing with Python.
#
# SUBMODULES
#     collect
#
# CLASSES
#     _pytest.nodes.FSCollector(_pytest.nodes.Collector)
#         _pytest.main.Session
#         _pytest.nodes.File
#             _pytest.python.Module(_pytest.nodes.File, _pytest.python.PyCollector)
#                 _pytest.python.Package
#     _pytest.nodes.Node(builtins.object)
#         _pytest.nodes.Collector
#         _pytest.nodes.Item
#             _pytest.python.Function(_pytest.python.FunctionMixin, _pytest.nodes.Item, _pytest.compat.FuncargnamesCompatAttr)
#     _pytest.python.FunctionMixin(_pytest.python.PyobjMixin)
#         _pytest.python.Function(_pytest.python.FunctionMixin, _pytest.nodes.Item, _pytest.compat.FuncargnamesCompatAttr)
#     _pytest.python.PyCollector(_pytest.python.PyobjMixin, _pytest.nodes.Collector)
#         _pytest.python.Class
#         _pytest.python.Instance
#     builtins.Exception(builtins.BaseException)
# ...

# %%
import pdb

# %%
pdb.set_trace()
(Pdb)
n : next line
s : step into func
c : continue the exe till end
r : execute till return stmt
l1 : long list
h : help
